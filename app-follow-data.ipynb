# %%
import pandas as pd

# %%
df = pd.read_csv("data/montessori_app_reviews.csv")

# %%
df.head()
# Out:
#              Submission date                              AppID  AppName  \
# 0  2024-06-19T16:49:17+00:00  com.edokicademy.montessoriacademy      NaN
# 1  2024-04-24T02:49:37+00:00  com.edokicademy.montessoriacademy      NaN
# 2  2024-04-15T01:13:16+00:00  com.edokicademy.montessoriacademy      NaN
# 3  2024-03-23T10:40:59+00:00  com.edokicademy.montessoriacademy      NaN
# 4  2024-02-23T18:42:31+00:00  com.edokicademy.montessoriacademy      NaN
#
#   Country Review Language  Version           Author  Rating  Title  \
# 0      us              en      NaN      James Arlow       2    NaN
# 1      us              en      NaN  Vincent Kezmann       5    NaN
# 2      us              en      NaN          stephen       2    NaN
# 3      us              en      NaN     Jernej Gomze       1    NaN
# 4      us              en      NaN    Jaime Quigley       1    NaN
#
#                                               Review  ...  Semantic Sentiment  \
# ...
