# %%
import pandas as pd
import numpy as np
from "serp-api.py" import
# Out:
#   File "C:\Users\Ryan Jewik\AppData\Local\Temp\ipykernel_24588\578208388.py", line 3
#     from serp-api.py import namelist
#              ^
# SyntaxError: invalid syntax

# %%
filename = "Montessori Preschool, kids 3-7 - Apps on Google Play.csv"

# %%
df = pd.read_csv(filename)
df.head()
# Out:
#                                      id               title  \
# 0  8547bb4e-5ba6-4e2e-98d3-47f7b1119e07  Christopher Bladek
# 1  1cccad67-9afc-4f50-a741-da694cf6d9d5        Valery Clark
# 2  da4c86e8-57a1-4491-8fa5-785dfbb2c53f         Austin Hill
# 3  633f5719-5a17-4c70-8488-c99be8dd7029                 Mau
# 4  172f2e04-59e1-4d1e-9825-0200fea0b529       A Google user
#
#                                               avatar  rating  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...     3.0
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...     5.0
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...     1.0
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...     1.0
# 4  https://play-lh.googleusercontent.com/EGemoI2N...     5.0
#
#                                              snippet  likes  \
# 0  It's interesting. Some of it works pretty well...    205
# 1  I am absolutely beside myself! I cannot begin ...     98
# 2  Pretty much everything you click on says subsc...     65
# 3  The app doesn't open, at the start freeze and ...      1
# 4  I tried the 7 day trial, and the app is well c...     77
#
#                  date              iso_date  \
# 0       July 15, 2021  2021-07-15T10:37:47Z
# 1   December 20, 2021  2021-12-20T19:13:38Z
# 2       July 12, 2023  2023-07-12T05:15:43Z
# 3  September 18, 2024  2024-09-18T18:42:54Z
# 4   November 27, 2019  2019-11-27T16:23:32Z
#
#                                             response
# 0  {'title': 'EDOKI ACADEMY', 'snippet': "Hello a...
# 1                                                NaN
# 2  {'title': 'EDOKI ACADEMY', 'snippet': 'Hello, ...
# 3  {'title': 'EDOKI ACADEMY', 'snippet': 'Hello, ...
# 4                                                NaN

# %%
random200 = df.sample(n=200, random_state=101)
random200.head()
# Out:
#                                        id          title  \
# 416  81e4eb94-53bc-485f-b836-c69277e51dd9  A Google user
# 325  638e42e2-e456-4b14-8c9f-d50c1f234297  A Google user
# 267  57e97cd9-8718-42d0-bb9e-e9ccd3f4dc0a      Nina Brus
# 241  5843af77-3e29-43a8-8c88-c0a4c3966b91  A Google user
# 858  d40378a9-9684-4325-8a71-19db5940850f  A Google user
#
#                                                 avatar  rating  \
# 416  https://play-lh.googleusercontent.com/EGemoI2N...     5.0
# 325  https://play-lh.googleusercontent.com/EGemoI2N...     3.0
# 267  https://play-lh.googleusercontent.com/a/ACg8oc...     5.0
# 241  https://play-lh.googleusercontent.com/EGemoI2N...     5.0
# 858  https://play-lh.googleusercontent.com/EGemoI2N...     4.0
#
#                                                snippet  likes  \
# 416  An application that offers the total pre schoo...      0
# 325  this is absolutely garbage terrible developer ...      0
# 267                        Great app, my kids love it.      0
# 241  My little fellow is able to attend Preschool r...      0
# 858                 Love the way it works for my kiddo      2
#
#                   date              iso_date  \
# 416  February 04, 2020  2020-02-04T15:48:43Z
# 325     March 07, 2020  2020-03-07T17:52:22Z
# 267      July 08, 2024  2024-07-08T16:12:05Z
# 241  November 09, 2019  2019-11-09T19:26:36Z
# 858     April 21, 2018  2018-04-21T13:22:55Z
#
#                                               response
# 416                                                NaN
# 325  {'title': 'EDOKI ACADEMY', 'snippet': 'Sorry a...
# 267                                                NaN
# 241                                                NaN
# 858                                                NaN

# %%
random200.shape
# Out:
# (200, 9)

# %%
newfile = "rand200-" + filename + ".csv"

# %%
df.to_csv(newfile, index = False)
